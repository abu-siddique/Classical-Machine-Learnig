# %%
import pandas as pd

# %%
pd.DataFrame({'yes':[31,131], 'no': [45,78]})
# Out:
#    yes  no
# 0   31  45
# 1  131  78

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']}, index=['prduct A', 'product B'])
# Out:
#                      Bob           Sue
# prduct A     I liked it.  Pretty good.
# product B  It was awful.        Bland.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 40, 70], index=['2015 sale', '2016 sale', '2017 sale'], name="Prdoduct A")
# Out:
# 2015 sale    30
# 2016 sale    40
# 2017 sale    70
# Name: Prdoduct A, dtype: int64

# %%
wine_reviews = pd.read_csv("../../data/external/wine-reviews/winemag-data-130k-v2.csv")

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews = pd.read_csv("../../data/external/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews = pd.read_csv("../../data/external/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows',5)

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country']
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %%
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
reviews.iloc[:, 0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.iloc[:3, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[1:3, 0]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[[0,1,2], 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[:2,'country']
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'title']]
# Out:
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# ...               ...                   ...
# 129969     Roger Voss            @vossroger
# 129970     Roger Voss            @vossroger
#
#                                                     title
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...                                                   ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
# [129971 rows x 3 columns]

# %%
reviews.set_index('title')
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %%
reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
reviews['index_backward'] = range(len(reviews), 0, -1)
reviews['index_backward']
# Out:
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: index_backward, Length: 129971, dtype: int64

# %%
reviews.loc[:,'description']
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
reviews.description.loc[0]
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
#              ...
# 75%          91.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %%
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews.points.mean()
# Out:
# np.float64(88.44713820775404)

# %%
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.taster_name.value_counts()
# Out:
# taster_name
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: count, Length: 19, dtype: int64

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p : p-review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.points
# Out:
# 0         87
# 1         87
#           ..
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64

# %%
def remean_point(row):
    row.points = row.points - review_points_mean
    return row
reviews.apply(remean_point, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
def remean(col):
    if col.dtype == 'int64':
        return col-review_points_mean
    return col
reviews.apply(remean, axis=0)
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
review_points_mean = reviews.points.mean()
reviews.points - review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.country + " - " + reviews.region_1
# Out:
# 0            Italy - Etna
# 1                     NaN
#                ...
# 129969    France - Alsace
# 129970    France - Alsace
# Length: 129971, dtype: object

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
reviews.points.value_counts()
# Out:
# points
# 88     17207
# 87     16933
#        ...
# 99        33
# 100       19
# Name: count, Length: 21, dtype: int64

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_6364\506966275.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0], include_groups=False)
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby(['country', 'province']).apply(lambda df : df.loc[df.points.idxmax()])
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_6364\1325527832.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby(['country', 'province']).apply(lambda df : df.loc[df.points.idxmax()])
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
# ...

# %%
reviews.groupby(['country']).price.agg([len, "min", "max"])
# Out:
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#      index country    province    len
# 392    392      US  California  36247
# 415    415      US  Washington   8639
# ..     ...     ...         ...    ...
# 395    395      US      Hawaii      1
# 399    399      US    Kentucky      1
#
# [425 rows x 4 columns]

# %%
countries_reviewed.sort_index()
# Out:
#      index    country          province   len
# 0        0  Argentina  Mendoza Province  3264
# 1        1  Argentina             Other   536
# ..     ...        ...               ...   ...
# 423    423    Uruguay          San Jose     3
# 424    424    Uruguay           Uruguay    24
#
# [425 rows x 4 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#      index    country          province   len
# 1        1  Argentina             Other   536
# 0        0  Argentina  Mendoza Province  3264
# ..     ...        ...               ...   ...
# 424    424    Uruguay           Uruguay    24
# 419    419    Uruguay         Canelones    43
#
# [425 rows x 4 columns]

# %%
reviews.groupby('price').points.max().sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
price_extremes = reviews.groupby('variety').price.agg(["min", "max"])
sorted_varieties = price_extremes.sort_values(by=['min','max'])
sorted_varieties
# Out:
#               min   max
# variety
# Pinot Grigio  4.0  70.0
# Malbec-Syrah  4.0  78.0
# ...           ...   ...
# Vital         NaN   NaN
# Zelen         NaN   NaN
#
# [707 rows x 2 columns]

# %%
reviews.groupby('taster_name').points.mean

# %%
reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Italy    Catalanesca              1
#          Carmenère                1
# Length: 1612, dtype: int64

# %%
reviews.points.dtype
# Out:
# dtype('int64')

# %%
reviews.dtypes
# Out:
# country           object
# description       object
#                    ...
# critic            object
# index_backward     int64
# Length: 15, dtype: object

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
#           ...
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %%
reviews[pd.notnull(reviews.country)]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.region_2.fillna('unknown')
# Out:
# 0         unknown
# 1         unknown
#            ...
# 129969    unknown
# 129970    unknown
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews[pd.isnull(reviews.price)].shape
# Out:
# (8996, 15)

# %%
pd.isnull(reviews.price).sum()
# Out:
# np.int64(8996)

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.rename(index={0: 'first_entry', 1: 'second_entry'})
# Out:
#                country                                        description  \
# first_entry      Italy  Aromas include tropical fruit, broom, brimston...
# second_entry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...                ...                                                ...
# 129969          France  A dry style of Pinot Gris, this is crisp with ...
# 129970          France  Big, rich and off-dry, this is powered by inte...
#
#                                 designation  points  price           province  \
# first_entry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# second_entry                       Avidagos      87   15.0              Douro
# ...                                     ...     ...    ...                ...
# 129969                                  NaN      90   32.0             Alsace
# 129970        Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %%
reviews.rename_axis('wines', axis='rows').rename_axis('fields', axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %%
reviews.drop(columns=['region_2'])
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1    taster_name taster_twitter_handle  \
# 0          Etna  Kerin O’Keefe          @kerinokeefe
# ...
