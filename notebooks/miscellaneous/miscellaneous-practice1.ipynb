# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
# Step 1: Create a synthetic dataset
X, y = make_classification(n_samples=1000, n_classes=2, random_state=42)

# Step 2: Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Step 4: Predict probabilities for the test set
y_scores = model.predict_proba(X_test)[:, 1]

# Step 5: Compute precision-recall curve values
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Step 6: Calculate F1 scores for each threshold
f1_scores = 2 * (precision * recall) / (precision + recall)

# Step 7: Plot the Precision-Recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision-Recall Curve', color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')

# Step 8: Highlight the maximum F1 score point
max_f1_idx = np.argmax(f1_scores)
best_f1 = f1_scores[max_f1_idx]
plt.scatter(recall[max_f1_idx], precision[max_f1_idx], color='r', label=f'Max F1 = {best_f1:.2f}')
plt.legend(loc='best')

# Show the plot
plt.show()

# Print the best F1 score
print(f"Best F1 Score: {best_f1}")
# Out:
# Best F1 Score: 0.8753993610223643

# %%
# Step 1: Create a synthetic dataset
X, y = make_classification(n_samples=1000, n_classes=2, random_state=42)

# Step 2: Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Step 4: Predict probabilities for the test set
y_scores = model.predict_proba(X_test)[:, 1]

# Step 5: Compute precision-recall curve values
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Step 6: Calculate F1 scores for each threshold
f1_scores = 2 * (precision * recall) / (precision + recall)

# Step 7: Plot the Precision-Recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision-Recall Curve', color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')

# Step 8: Highlight the maximum F1 score point
max_f1_idx = np.argmax(f1_scores)
best_f1 = f1_scores[max_f1_idx]
plt.scatter(recall[max_f1_idx], precision[max_f1_idx], color='r', label=f'Max F1 = {best_f1:.2f}')
plt.legend(loc='best')

# Show the plot
plt.show()

# Print the best F1 score
print(f"Best F1 Score: {best_f1}")
# Out:
# Best F1 Score: 0.8753993610223643

# %%
# Step 1: Create a synthetic dataset
X, y = make_classification(n_samples=1000, n_classes=2, random_state=42)

# Step 2: Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Step 4: Predict probabilities for the test set
y_scores = model.predict_proba(X_test)[:, 1]

# Step 5: Compute precision-recall curve values
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Step 6: Calculate F1 scores for each threshold
f1_scores = 2 * (precision * recall) / (precision + recall)

# Step 7: Plot the Precision-Recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision-Recall Curve', color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')

# Step 8: Highlight the maximum F1 score point
max_f1_idx = np.argmax(f1_scores)
best_f1 = f1_scores[max_f1_idx]
plt.scatter(recall[max_f1_idx], precision[max_f1_idx], color='r', label=f'Max F1 = {best_f1:.2f}')
plt.legend(loc='best')

# Show the plot
plt.show()

# Print the best F1 score
print(f"Best F1 Score: {best_f1}")
# Out:
# Best F1 Score: 0.8753993610223643

# %%
# Step 1: Create a synthetic dataset
X, y = make_classification(n_samples=1000, n_classes=2, random_state=42)

# Step 2: Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Train different models
model1 = LogisticRegression()
model2 = RandomForestClassifier()
model3 = SVC(probability=True)

# Fit models
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train)

# Step 4: Predict probabilities for the test set
y_scores1 = model1.predict_proba(X_test)[:, 1]
y_scores2 = model2.predict_proba(X_test)[:, 1]
y_scores3 = model3.predict_proba(X_test)[:, 1]

# Step 5: Compute precision-recall curves
precision1, recall1, _ = precision_recall_curve(y_test, y_scores1)
precision2, recall2, _ = precision_recall_curve(y_test, y_scores2)
precision3, recall3, _ = precision_recall_curve(y_test, y_scores3)

# Step 6: Plot the Precision-Recall curves
plt.figure(figsize=(10, 8))
plt.plot(recall1, precision1, label='Logistic Regression', color='b')
plt.plot(recall2, precision2, label='Random Forest', color='g')
plt.plot(recall3, precision3, label='SVM', color='r')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc='best')
plt.show()

# You can also calculate the average F1 score for each model to decide which one is better.
f1_scores1 = 2 * (precision1 * recall1) / (precision1 + recall1)
f1_scores2 = 2 * (precision2 * recall2) / (precision2 + recall2)
f1_scores3 = 2 * (precision3 * recall3) / (precision3 + recall3)

# Print the maximum F1 score for each model
print(f"Max F1 Score for Logistic Regression: {np.max(f1_scores1):.2f}")
print(f"Max F1 Score for Random Forest: {np.max(f1_scores2):.2f}")
print(f"Max F1 Score for SVM: {np.max(f1_scores3):.2f}")
# Out:
# Max F1 Score for Logistic Regression: 0.88
# Max F1 Score for Random Forest: 0.87
# Max F1 Score for SVM: 0.86

# %%
# Step 1: Generate synthetic dataset
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=42)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 2: Train classifiers
model1 = LogisticRegression()
model2 = RandomForestClassifier()
model3 = GradientBoostingClassifier()

# Fit models
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train)

# Predict probabilities
y_scores_model1 = model1.predict_proba(X_test)[:, 1]
y_scores_model2 = model2.predict_proba(X_test)[:, 1]
y_scores_model3 = model3.predict_proba(X_test)[:, 1]

# Step 3: Compute ROC curves and AUC
fpr1, tpr1, _ = roc_curve(y_test, y_scores_model1)
roc_auc1 = auc(fpr1, tpr1)

fpr2, tpr2, _ = roc_curve(y_test, y_scores_model2)
roc_auc2 = auc(fpr2, tpr2)

fpr3, tpr3, _ = roc_curve(y_test, y_scores_model3)
roc_auc3 = auc(fpr3, tpr3)

# Plot ROC curves
plt.figure()
plt.plot(fpr1, tpr1, color='blue', lw=2, label=f'Logistic Regression (AUC = {roc_auc1:.2f})')
plt.plot(fpr2, tpr2, color='green', lw=2, label=f'Random Forest (AUC = {roc_auc2:.2f})')
plt.plot(fpr3, tpr3, color='red', lw=2, label=f'Gradient Boosting (AUC = {roc_auc3:.2f})')

# Plot diagonal line (random classifier)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# Customize the plot
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
# Generate synthetic data
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train models
model1 = LogisticRegression()
model2 = RandomForestClassifier()
model3 = GradientBoostingClassifier()
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train)

# Predict probabilities
y_scores_model1 = model1.predict_proba(X_test)[:, 1]
y_scores_model2 = model2.predict_proba(X_test)[:, 1]
y_scores_model3 = model3.predict_proba(X_test)[:, 1]

# Calculate ROC curve and AUC for each model
def calculate_roc(y_true, y_scores):
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)
    return fpr, tpr, thresholds, roc_auc

fpr1, tpr1, thresholds1, roc_auc1 = calculate_roc(y_test, y_scores_model1)
fpr2, tpr2, thresholds2, roc_auc2 = calculate_roc(y_test, y_scores_model2)
fpr3, tpr3, thresholds3, roc_auc3 = calculate_roc(y_test, y_scores_model3)

# Calculate Precision-Recall curve and F1 score for each model
def calculate_precision_recall_f1(y_true, y_scores):
    precisions, recalls, thresholds = precision_recall_curve(y_true, y_scores)
    f1_scores = 2 * (precisions * recalls) / (precisions + recalls)
    return precisions, recalls, thresholds, f1_scores

precisions1, recalls1, thresholds1_pr, f1_scores1 = calculate_precision_recall_f1(y_test, y_scores_model1)
precisions2, recalls2, thresholds2_pr, f1_scores2 = calculate_precision_recall_f1(y_test, y_scores_model2)
precisions3, recalls3, thresholds3_pr, f1_scores3 = calculate_precision_recall_f1(y_test, y_scores_model3)

# Find the threshold that maximizes the F1 score for each model
best_threshold1 = thresholds1_pr[np.argmax(f1_scores1)]
best_threshold2 = thresholds2_pr[np.argmax(f1_scores2)]
best_threshold3 = thresholds3_pr[np.argmax(f1_scores3)]

print(f'Best Threshold (Model 1): {best_threshold1}')
print(f'Best Threshold (Model 2): {best_threshold2}')
print(f'Best Threshold (Model 3): {best_threshold3}')

# Plot ROC curves
plt.figure()
plt.plot(fpr1, tpr1, color='blue', lw=2, label=f'Logistic Regression (AUC = {roc_auc1:.2f})')
plt.plot(fpr2, tpr2, color='green', lw=2, label=f'Random Forest (AUC = {roc_auc2:.2f})')
plt.plot(fpr3, tpr3, color='red', lw=2, label=f'Gradient Boosting (AUC = {roc_auc3:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# Best Threshold (Model 1): 0.42920097042278993
# Best Threshold (Model 2): 0.46
# Best Threshold (Model 3): 0.510455078824291

# %%
# Generate an imbalanced dataset with 1000 points
X, y = make_classification(n_samples=1000, n_features=20, n_informative=2, n_redundant=10, 
                           n_clusters_per_class=1, weights=[0.95, 0.05], random_state=42)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a Logistic Regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict probabilities
y_pred_proba = model.predict_proba(X_test)[:, 1]
y_pred = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title(f'ROC Curve for Imbalanced Dataset (Accuracy = {accuracy:.2f})')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[281   2]
#  [  3  14]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, accuracy_score, confusion_matrix
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# Generate an imbalanced dataset with 1000 points
X, y = make_classification(n_samples=1000, n_features=20, n_informative=2, n_redundant=10, 
                           n_clusters_per_class=1, weights=[0.95, 0.05], random_state=42)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a Logistic Regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict probabilities
y_pred_proba = model.predict_proba(X_test)[:, 1]
y_pred = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title(f'ROC Curve for Imbalanced Dataset (Accuracy = {accuracy:.2f})')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# Print confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

print("Confusion Matrix:\n", cm)

# Plot TPR vs Threshold
plt.figure(figsize=(8,6))
plt.plot(thresholds, tpr[:-1], color='green', lw=2, label='TPR (True Positive Rate)')
plt.xlabel('Threshold')
plt.ylabel('True Positive Rate (TPR)')
plt.title('TPR vs Threshold')
plt.grid(True)
plt.legend(loc='lower right')
plt.show()

# Plot FPR vs Threshold
plt.figure(figsize=(8,6))
plt.plot(thresholds, fpr[:-1], color='red', lw=2, label='FPR (False Positive Rate)')
plt.xlabel('Threshold')
plt.ylabel('False Positive Rate (FPR)')
plt.title('FPR vs Threshold')
plt.grid(True)
plt.legend(loc='upper right')
plt.show()
# Out:
# Confusion Matrix:
#  [[281   2]
#  [  3  14]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\MLProjects\Classical-Machine-Learnig\notebooks\miscellaneous\miscellaneous-practice1.ipynb Cell 9 line 5
#      <a href='vscode-notebook-cell:/d%3A/MLProjects/Classical-Machine-Learnig/notebooks/miscellaneous/miscellaneous-practice1.ipynb#X11sZmlsZQ%3D%3D?line=56'>57</a> # Plot TPR vs Threshold
#      <a href='vscode-notebook-cell:/d%3A/MLProjects/Classical-Machine-Learnig/notebooks/miscellaneous/miscellaneous-practice1.ipynb#X11sZmlsZQ%3D%3D?line=57'>58</a> plt.figure(figsize=(8,6))
# ---> <a href='vscode-notebook-cell:/d%3A/MLProjects/Classical-Machine-Learnig/notebooks/miscellaneous/miscellaneous-practice1.ipynb#X11sZmlsZQ%3D%3D?line=58'>59</a> plt.plot(thresholds, tpr[:-1], color='green', lw=2, label='TPR (True Positive Rate)')
# ...
